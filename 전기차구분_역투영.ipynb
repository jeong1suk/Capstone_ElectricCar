# %% [markdown]
# <a href="https://colab.research.google.com/github/jeong1suk/Capstone_ElectricCar/blob/beoman/%EC%A0%84%EA%B8%B0%EC%B0%A8%EA%B5%AC%EB%B6%84_%EC%97%AD%ED%88%AC%EC%98%81.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

src = cv2.imread('연습2.jpg')

src = src[528: 577,476:715]
#print(src.shape)
#x, y, w, h = cv2.selectROI(src)

src_ycrcb = cv2.cvtColor(src, cv2.COLOR_BGR2YCrCb)
crop = src_ycrcb[20: 40, 10: 20]
img = src
img = cv2.rectangle(img, (20,40), (10,20), (0,0,255), 2)
cv2_imshow(img)

channels = [1, 2]

cr_bins = 128
cb_bins = 128
histSize = [cr_bins, cb_bins]

cr_range = [0, 256]
cb_range = [0, 256]
ranges = cr_range + cb_range
hist = cv2.calcHist([crop], channels, None, histSize, ranges)
hist_norm = cv2.normalize(hist, None, 0, 255, cv2.NORM_MINMAX, cv2.CV_8U)

backproj = cv2.calcBackProject([src_ycrcb], channels, hist, ranges, 3)
dst = cv2.copyTo(src, backproj)

ret, dst123 = cv2.threshold(backproj, 0, 255, cv2.THRESH_BINARY)

print(type(dst123))
print(src.shape)
print(backproj.shape)

cv2_imshow(src)
cv2_imshow(hist_norm)
cv2_imshow(backproj)
cv2_imshow(dst123)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=239x49 at 0x7FB15CE0E0D0>
# <class 'numpy.ndarray'>
# (49, 239, 3)
# (49, 239)
# <PIL.Image.Image image mode=RGB size=239x49 at 0x7FB15CE0E0D0>
# <PIL.Image.Image image mode=L size=128x128 at 0x7FB15CE0E190>
# <PIL.Image.Image image mode=L size=239x49 at 0x7FB15CE0ED50>
# <PIL.Image.Image image mode=L size=239x49 at 0x7FB15CE0EB90>
# <PIL.Image.Image image mode=RGB size=239x49 at 0x7FB15CE0E1D0>

# %%
src2 = cv2.imread('전기차2.jpg')
src2 = src2[309:348, 222: 339]

cv2_imshow(src2)

src2_ycrcb = cv2.cvtColor(src2, cv2.COLOR_BGR2YCrCb)

crop2 = src2_ycrcb[10: 20, 10: 20]

img = src2
img = cv2.rectangle(img, (10,20), (10,20), (0,0,255), 3)
cv2_imshow(img)

channels = [1, 2]

cr_bins = 128
cb_bins = 128
histSize = [cr_bins, cb_bins]

cr_range = [0, 256]
cb_range = [0, 256]
ranges = cr_range + cb_range
hist2 = cv2.calcHist([crop2], channels, None, histSize, ranges)
hist2_norm = cv2.normalize(hist2, None, 0, 255, cv2.NORM_MINMAX, cv2.CV_8U)
cv2_imshow(hist2_norm)

backproj2 = cv2.calcBackProject([src2_ycrcb], channels, hist2, ranges, 1)

print(src2.shape)
print(backproj2.shape)
#re = cv2.resize(src2, dsize = (backproj.shape[1],backproj.shape[0]))
#print(re.shape)

ret, dst1234 = cv2.threshold(backproj2, 0, 255, cv2.THRESH_BINARY)

cv2_imshow(dst1234)
dst2 = cv2.copyTo(src2, backproj2)

cv2_imshow(backproj2)
cv2_imshow(dst2)
print(dst2.shape)
# Out:
# <PIL.Image.Image image mode=RGB size=117x39 at 0x7FB15C293F50>
# <PIL.Image.Image image mode=RGB size=117x39 at 0x7FB16FFFEC90>
# <PIL.Image.Image image mode=L size=128x128 at 0x7FB15CE0E9D0>
# (39, 117, 3)
# (39, 117)
# <PIL.Image.Image image mode=L size=117x39 at 0x7FB15C3F7610>
# <PIL.Image.Image image mode=L size=117x39 at 0x7FB15CE0E050>
# <PIL.Image.Image image mode=RGB size=117x39 at 0x7FB16FFFE8D0>
# (39, 117, 3)

# %%
src3 = cv2.imread('전기차.jpg')
src3 = src3[594:628, 503: 711]

cv2_imshow(src3)

src3_ycrcb = cv2.cvtColor(src3, cv2.COLOR_BGR2YCrCb)

crop3 = src3_ycrcb[10: 30, 15: 20]

img = src3
img = cv2.rectangle(img, (10,30), (15,20), (0,0,255), 2)
cv2_imshow(img)

channels = [1, 2]

cr_bins = 128
cb_bins = 128
histSize = [cr_bins, cb_bins]

cr_range = [0, 256]
cb_range = [0, 256]
ranges = cr_range + cb_range
hist3 = cv2.calcHist([crop3], channels, None, histSize, ranges)
hist3_norm = cv2.normalize(hist3, None, 1, 255, cv2.NORM_MINMAX, cv2.CV_8U)
cv2_imshow(hist3_norm)

backproj3 = cv2.calcBackProject([src3_ycrcb], channels, hist3, ranges, 1)

print(src3.shape)
print(backproj3.shape)
#re = cv2.resize(src3, dsize = (backproj.shape[1],backproj.shape[0]))
#print(re.shape)

ret, dst123456 = cv2.threshold(backproj3, 0, 255, cv2.THRESH_BINARY)

cv2_imshow(dst123456)
dst2 = cv2.copyTo(src3, backproj3)

cv2_imshow(backproj3)
cv2_imshow(dst2)
print(dst2.shape)
# Out:
# <PIL.Image.Image image mode=RGB size=208x34 at 0x7FB15C3F7790>
# <PIL.Image.Image image mode=RGB size=208x34 at 0x7FB15C3F7790>
# <PIL.Image.Image image mode=L size=128x128 at 0x7FB15C3F7790>
# (34, 208, 3)
# (34, 208)
# <PIL.Image.Image image mode=L size=208x34 at 0x7FB15C3F7790>
# <PIL.Image.Image image mode=L size=208x34 at 0x7FB15C2A11D0>
# <PIL.Image.Image image mode=RGB size=208x34 at 0x7FB15C2A1B90>
# (34, 208, 3)

# %%
src6 = cv2.imread('저녁전등.jpg')
src6 = src6[458:542,522:1037]

cv2_imshow(src6)

src6_ycrcb = cv2.cvtColor(src6, cv2.COLOR_BGR2YCrCb)

crop6 = src6_ycrcb[10: 50, 10: 20]

img = src6
img = cv2.rectangle(img, (10,50), (30,20), (0,0,255), 2)
cv2_imshow(img)

channels = [1, 2]

cr_bins = 128
cb_bins = 128
histSize = [cr_bins, cb_bins]

cr_range = [0, 256]
cb_range = [0, 256]
ranges = cr_range + cb_range
hist6 = cv2.calcHist([crop6], channels, None, histSize, ranges)
hist6_norm = cv2.normalize(hist6, None, 0, 255, cv2.NORM_MINMAX, cv2.CV_8U)
cv2_imshow(hist6_norm)

backproj6 = cv2.calcBackProject([src6_ycrcb], channels, hist6, ranges, 1)

print(src6.shape)
print(backproj6.shape)
#re = cv2.resize(src6, dsize = (backproj.shape[1],backproj.shape[0]))
#print(re.shape)

ret, dst6 = cv2.threshold(backproj6, 1, 255, cv2.THRESH_BINARY)

cv2_imshow(dst6)
dst6 = cv2.copyTo(src6, backproj6)

cv2_imshow(backproj6)
cv2_imshow(dst6)
# Out:
# <PIL.Image.Image image mode=RGB size=515x84 at 0x7FB15C2A10D0>
# <PIL.Image.Image image mode=RGB size=515x84 at 0x7FB15C2A1850>
# <PIL.Image.Image image mode=L size=128x128 at 0x7FB15C2A1ED0>
# (84, 515, 3)
# (84, 515)
# <PIL.Image.Image image mode=L size=515x84 at 0x7FB15C329B10>
# <PIL.Image.Image image mode=L size=515x84 at 0x7FB15C329DD0>
# <PIL.Image.Image image mode=RGB size=515x84 at 0x7FB15C329410>

# %%
import numpy as np
n_hist = hist + hist2 + hist3 + hist6

'''for i in  range(128):
  for j in range(128):
    if hist[i][j] == 0 or hist2[i][j] == 0:
      n_hist[i][j] = hist[i][j] + hist2[i][j]
    else:
    n_hist[i][j] = hist[i][j]'''


cr_range = [0, 256]
cb_range = [0, 256]
ranges = cr_range + cb_range
n_hist_norm = cv2.normalize(n_hist, None, 0, 255, cv2.NORM_MINMAX, cv2.CV_8U)


cv2_imshow(hist_norm)
cv2_imshow(hist2_norm)
cv2_imshow(hist3_norm)
cv2_imshow(hist6_norm)
cv2_imshow(n_hist_norm)
# Out:
# <PIL.Image.Image image mode=L size=128x128 at 0x7FB15C2931D0>
# <PIL.Image.Image image mode=L size=128x128 at 0x7FB15C2934D0>
# <PIL.Image.Image image mode=L size=128x128 at 0x7FB15C293290>
# <PIL.Image.Image image mode=L size=128x128 at 0x7FB15C293B10>
# <PIL.Image.Image image mode=L size=128x128 at 0x7FB15C293D90>

# %%
src4 = cv2.imread('전기차3.jpg')
src4 = src4[563:605,535:754]
src4_ycrcb = cv2.cvtColor(src4, cv2.COLOR_BGR2YCrCb)

channels = [1, 2]
cr_range = [0, 256]
cb_range = [0, 256]
ranges = cr_range + cb_range

backproj5 = cv2.calcBackProject([src4_ycrcb], channels, n_hist, ranges, 1)
#dst4 = cv2.copyTo(src4, backproj5)
ret, dst123456 = cv2.threshold(backproj5, 0,255, cv2.THRESH_BINARY)
cv2_imshow(src4)
cv2_imshow(backproj5)
cv2_imshow(dst123456)
#cv2_imshow(dst4)
# Out:
# <PIL.Image.Image image mode=RGB size=219x42 at 0x7FB15C2CB610>
# <PIL.Image.Image image mode=L size=219x42 at 0x7FB16E51CE10>
# <PIL.Image.Image image mode=L size=219x42 at 0x7FB15DE73550>

# %%
'''channels = [1, 2]

cr_bins = 128
cb_bins = 128
histSize = [cr_bins, cb_bins]

cr_range = [0, 256]
cb_range = [0, 256]
ranges = cr_range + cb_range'''

# %%
#backproj = cv2.calcBackProject([src_ycrcb], channels, hist, ranges, 1)

# %%
#dst = cv2.copyTo(src,backproj)

# %%
#cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=208x34 at 0x7FBC01CB8250>

# %%
print(dst123456.shape)
h,w= dst123456.shape
isElectronic = 0 
notElectronic = 0

#gray = cv2.cvtColor(dst123456, cv2.COLOR_BGR2GRAY)
ret, dst123456 = cv2.threshold(dst123456, 2, 255, cv2.THRESH_BINARY)

cv2_imshow(dst123456)

for y in range(h):
    for x in range(w):
        if dst123456[y, x] >= 1: # 픽셀 값이 1 이상이면 전기차로 가정
            isElectronic += 1
        else:
            notElectronic += 1
                                  
print(isElectronic, notElectronic)
            
if 10 * isElectronic >= notElectronic: # 10배(하이퍼 파라미터) 이상 차이가 나면 전기자동차로 인식
    print("전기 자동차")

else:
    print("전기 자동차 아님")
# Out:
# (35, 64)
# <PIL.Image.Image image mode=L size=64x35 at 0x7FB15CE0EB90>
# 445 1795
# 전기 자동차
